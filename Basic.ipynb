# %%
a=100
print(a)
# Out:
# 100

# %%
a=6.7
a1=False
a2="Python"
a3=5+7j
print(type(a))
print(type(a1))
print(type(a2))
print(type(a3))
# Out:
# <class 'float'>
# <class 'bool'>
# <class 'str'>
# <class 'complex'>

# %%
a=0b110011
print(a)
a1=0x56d
print(oct(a1))
a2=0o6544
print(hex(a))
# Out:
# 51
# 0o2555
# 0x33

# %%
a=10.5
a1=45.3
a2="67"
a3=True
print(int(a))
print(int(a1))
print(int(a2))
print(int(a3))
# Out:
# 10
# 45
# 67
# 1

# %%
a=True
print(float(a))
# Out:
# 1.0

# %%
a=15
print(str(a)+"10")
# Out:
# 1510

# %%
a=15
a1=0
a2=""
a3=0.0
print(bool(a))
print(bool(a1))
print(bool(a2))
print(bool(a3))
# Out:
# True
# False
# False
# False

# %%
a=5+6j
print(a.real)
print(a.imag)
# Out:
# 5.0
# 6.0
