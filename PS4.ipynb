# %%
def greet():
    print("Hello, Python Learner!")

greet()
# Out:
# Hello, Python Learner!

# %%
def square(num):
    return num * num

result = square(5)
result1 = square(10)
print(result)
print(result1)
# Out:
# 25
# 100

# %%
def full_name(first_name, last_name):
    full_name = f"{first_name} {last_name}"
    return full_name

name = full_name("Sarthak", "Mahurkar")
print(name)
# Out:
# Sarthak Mahurkar

# %%
def calculate_area(length, width = 10):
    area_rectangle = length * width
    return area_rectangle

area1 = calculate_area(5, 8)
area2 = calculate_area(7)
print(area1)
print(area2)
# Out:
# 40
# 70

# %%
sum = lambda a, b: a + b
result = sum(5, 10)
print(result)
# Out:
# 15

# %%
My_list1 = [1, 2, 3, 4, 5]
squared_list = lambda x: x*x
# squared_list = list(map(lambda x: x ** 2, My_list1))
# print(squared_list)
print(list(map(squared_list, My_list1)))
# Out:
# [1, 4, 9, 16, 25]

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)
    
print(factorial(5))
# Out:
# 120

# %%
def sum_of_digits(n):
    if n == 0:
        return 0
    else:
        return n % 10 + sum_of_digits(n // 10)

print(sum_of_digits(123))
# Out:
# 6

# %%
import math
sqrt = lambda x: math.sqrt(x)
result = sqrt(144)
print(result)
# Out:
# 12.0

# %%
import math
sin = lambda x: math.sin(math.radians(x))
cos = lambda x: math.cos(math.radians(x))
# sin = math.sin(math.radians(90))
print(sin(90))
print(cos(0))
# Out:
# 1.0
# 1.0

# %%
import requests
response = requests.get("https://api.github.com")
print(response.json())
# Out:
# {'current_user_url': 'https://api.github.com/user', 'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}', 'authorizations_url': 'https://api.github.com/authorizations', 'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}', 'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}', 'emails_url': 'https://api.github.com/user/emails', 'emojis_url': 'https://api.github.com/emojis', 'events_url': 'https://api.github.com/events', 'feeds_url': 'https://api.github.com/feeds', 'followers_url': 'https://api.github.com/user/followers', 'following_url': 'https://api.github.com/user/following{/target}', 'gists_url': 'https://api.github.com/gists{/gist_id}', 'hub_url': 'https://api.github.com/hub', 'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}', 'issues_url': 'https://api.github.com/issues', 'keys_url': 'https://api.g
# ...

# %%
def increment():
    counter = 0
    counter += 1
    print(f"Counter incremented to: {counter}")
    return counter

increment()
increment()
increment()
increment()
# Out:
# Counter incremented to: 1
# Counter incremented to: 1
# Counter incremented to: 1
# Counter incremented to: 1
# 1

# %%
def multiply(a, b):
    ''' a function that multiplies two numbers 
    Parameters:
    a (int or float): The first number to multiply.
    b (int or float): The second number to multiply.
    Returns:
    int or float: The product of a and b.
    ''' 
    return a * b
help(multiply)
# Out:
# Help on function multiply in module __main__:
#
# multiply(a, b)
#     a function that multiplies two numbers
#     Parameters:
#     a (int or float): The first number to multiply.
#     b (int or float): The second number to multiply.
#     Returns:
#     int or float: The product of a and b.

# %%
def fibonacci(n):
    fno = 0
    sno = 1
    if n <= 0:
        print("Please enter a number greater than 0.")
        return []
    elif n == 1:
        return [fno]
    elif n == 2:
        return [fno, sno]
    else:
        fib_sequence = [fno, sno]
        for i in range(2, n):
            next_number = fib_sequence[i - 1] + fib_sequence[i - 2]
            fib_sequence.append(next_number)
        return fib_sequence
    
print(fibonacci(5))
# Out:
# Please enter a number greater than 0.
# []

# %%
def self_divide(a, b):
    if b == 0:
        print("Cannot divide by zero.")
        return None
    result = a / b
    return result
print(self_divide(10, 3))
# Out:
# 3.3333333333333335

# %%
import my_utils

print(my_utils.is_even(2))
# Out:
# True
