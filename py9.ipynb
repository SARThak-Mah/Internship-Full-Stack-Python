# %%
# Sting=>
s1='cnc webworld'
s2="cnc webworld"
s3='cnc "web" world'
s4="cnc 'web' world"
print(s1)
print(s2)
print(s3)
print(s4)
# Out:
# cnc webworld
# cnc webworld
# cnc "web" world
# cnc 'web' world

# %%
s='''cnc web
world'''
print(s)

s1="""cnc web world"""
print(s1)
# Out:
# cnc web
# world
# cnc web world

# %%
s="""
s='''cnc'''
"""
print(s)
# Out:
# s='''cnc'''

# %%
name="Sarthak"
age=20
loc="Nerul"

s=f"my name is {name} and age is {age} and location is {loc}"

print(s)
print(
    f"my name is {name} and age is {age} and location is {loc}"
)
# Out:
# my name is Sarthak and age is 20 and location is Nerul
# my name is Sarthak and age is 20 and location is Nerul

# %%
s="this is cnc \nweb world \t in nerul"
print(s)

s1="this is cnc \\n web world \\t in nerul"
print(s1)

p=r"c:\new\target\file.txt"
print(p)
# Out:
# this is cnc
# web world 	 in nerul
# this is cnc \n web world \t in nerul
# c:\new\target\file.txt

# %%
#Exception Handling=>
# print(1)
# print(2)
# print(3)
try:
    a=10
    b=5
    # b = 0
    c=a/b
    print("Div:",c)
    
    
except Exception as e:
    print(e)
else:
    print("No any exception in try block")
    
    
# print(4)
# print(5)
# print(6)
# print(7)
# Out:
# division by zero

# %%
class AgeException(Exception):
    pass


class Voting:
    def age(self,a):
        if a<18:
            raise AgeException()
        else:
            print("Age is greter than 18")



user=Voting()
try:
    # user.age(15)
    user.age(20)
    print("You are Elligible for voting")
    print("We can proceed Next step for voting")

except AgeException as e:
    print("You are Not Elligible for voting")
# Out:
# Age is greter than 18
# YOu are Elligible for voting
# We can proceed Next step for voting
